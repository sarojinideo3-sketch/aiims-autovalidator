# %% [markdown]
# <a href="https://colab.research.google.com/github/sarojinideo3-sketch/aiims-autovalidator/blob/main/Starlight1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata

# Configure my gemini API key
# Access the API key from Colab secrets.
genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))

# Load Gemini pro model
model = genai.GenerativeModel("gemini-2.5-flash-lite")

# Define a very simple function for the agent
def simple_agent(prompt):
    response = model.generate_content(prompt)
    return response.text

# Try first prompt
question = "Can you explain the difference between external and internal qc in lab medicine"
answer = simple_agent(question)

print("Ques: ", question)
print("Answer:", answer)
# Out:
# Ques:  Can you explain the difference between external and internal qc in lab medicine
# Answer: In lab medicine, **Quality Control (QC)** is a crucial process to ensure the accuracy, reliability, and validity of laboratory test results. It's about verifying that the laboratory's procedures, equipment, and personnel are functioning correctly. There are two main categories of QC: **external QC** and **internal QC**.
#
# Here's a breakdown of the differences:
#
# ## Internal Quality Control (IQC)
#
# **Definition:** Internal QC involves **regular testing performed within the laboratory itself** using materials of known or assigned values to monitor the performance of analytical instruments, reagents, and the overall testing process.
#
# **Key Characteristics:**
#
# *   **Performed by Lab Personnel:** Lab technologists and technicians are responsible for preparing, running, and evaluating IQC.
# ...
